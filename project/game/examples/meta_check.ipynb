# %% [markdown]
# ## проверим BotMeta:

# %% [markdown]
# `main.py`:
# ![image-3.png](attachment:image-3.png)
#
# `bot.py`:
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)
#
# `example_run.txt`:
# ```sql
# --- Round 1 ---
# Bot1 draws 9 of Diamonds
# Bot2 stays with score 0
# Bot3 stays with score 0
#
# Current game state:
# Bot1 (ConservativeBot) score: 9 | Hand: [9 of Diamonds]
# Bot2 (AggressiveBot) score: 0 | Hand: []
# Bot3 (MixedBot) score: 0 | Hand: []
#
#
# --- Round 2 ---
# Bot1 draws 7 of Clubs
# Bot2 stays with score 0
# Bot3 stays with score 0
#
# Current game state:
# Bot1 (ConservativeBot) score: 16 | Hand: [9 of Diamonds, 7 of Clubs]
# Bot2 (AggressiveBot) score: 0 | Hand: []
# Bot3 (MixedBot) score: 0 | Hand: []
#
#
# --- Round 3 ---
# Bot1 stays with score 16
# Bot2 stays with score 0
# Bot3 stays with score 0
#
# Current game state:
# Bot1 (ConservativeBot) score: 16 | Hand: [9 of Diamonds, 7 of Clubs]
# Bot2 (AggressiveBot) score: 0 | Hand: []
# Bot3 (MixedBot) score: 0 | Hand: []
#
#
# --- Round 4 ---
# Bot1 stays with score 16
# Bot2 stays with score 0
# Bot3 stays with score 0
#
# Current game state:
# Bot1 (ConservativeBot) score: 16 | Hand: [9 of Diamonds, 7 of Clubs]
# Bot2 (AggressiveBot) score: 0 | Hand: []
# Bot3 (MixedBot) score: 0 | Hand: []
#
#
# --- Round 5 ---
# Bot1 stays with score 16
# Bot2 stays with score 0
# Bot3 stays with score 0
#
# Current game state:
# Bot1 (ConservativeBot) score: 16 | Hand: [9 of Diamonds, 7 of Clubs]
# Bot2 (AggressiveBot) score: 0 | Hand: []
# Bot3 (MixedBot) score: 0 | Hand: []
#
#
# --- Round 6 ---
# Bot1 stays with score 16
# Bot2 stays with score 0
# Bot3 stays with score 0
#
# Current game state:
# Bot1 (ConservativeBot) score: 16 | Hand: [9 of Diamonds, 7 of Clubs]
# Bot2 (AggressiveBot) score: 0 | Hand: []
# Bot3 (MixedBot) score: 0 | Hand: []
#
#
# --- Round 7 ---
# Bot1 stays with score 16
# Bot2 stays with score 0
# Bot3 stays with score 0
#
# Current game state:
# Bot1 (ConservativeBot) score: 16 | Hand: [9 of Diamonds, 7 of Clubs]
# Bot2 (AggressiveBot) score: 0 | Hand: []
# Bot3 (MixedBot) score: 0 | Hand: []
#
#
# --- Round 8 ---
# Bot1 stays with score 16
# Bot2 stays with score 0
# Bot3 stays with score 0
#
# Current game state:
# Bot1 (ConservativeBot) score: 16 | Hand: [9 of Diamonds, 7 of Clubs]
# Bot2 (AggressiveBot) score: 0 | Hand: []
# Bot3 (MixedBot) score: 0 | Hand: []
#
#
# --- Round 9 ---
# Bot1 stays with score 16
# Bot2 stays with score 0
# Bot3 stays with score 0
#
# Current game state:
# Bot1 (ConservativeBot) score: 16 | Hand: [9 of Diamonds, 7 of Clubs]
# Bot2 (AggressiveBot) score: 0 | Hand: []
# Bot3 (MixedBot) score: 0 | Hand: []
#
#
# --- Round 10 ---
# Bot1 stays with score 16
# Bot2 stays with score 0
# Bot3 stays with score 0
#
# Current game state:
# Bot1 (ConservativeBot) score: 16 | Hand: [9 of Diamonds, 7 of Clubs]
# Bot2 (AggressiveBot) score: 0 | Hand: []
# Bot3 (MixedBot) score: 0 | Hand: []
#
# Game over: Bot1 wins with a score of 16!
# ```

# %% [markdown]
# ## Проверим target_score:

# %% [markdown]
# `main.py`:
# ![image.png](attachment:image.png)
#
# `example_run.txt`:
# ```sql
# --- Round 1 ---
# Bot1 draws 4 of Spades
# Bot2 draws 13 of Spades
# Bot3 draws 8 of Hearts
#
# Current game state:
# Bot1 (ConservativeBot) score: 4 | Hand: [4 of Spades]
# Bot2 (AggressiveBot) score: 10 | Hand: [13 of Spades]
# Bot3 (MixedBot) score: 8 | Hand: [8 of Hearts]
#
# Game over: Bot2 wins with 10 points!
# ```
